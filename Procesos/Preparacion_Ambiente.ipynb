-- %%
%python
dbutils.widgets.removeAll()
dbutils.widgets.text("storageName", "adlslakedev006")

storageName = dbutils.widgets.get("storageName")

spark.sql("DROP CATALOG IF EXISTS catalog_smartdata CASCADE")
spark.sql("CREATE CATALOG IF NOT EXISTS catalog_smartdata")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalog_smartdata.raw")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalog_smartdata.bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalog_smartdata.silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalog_smartdata.golden")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalog_smartdata.exploratory")
