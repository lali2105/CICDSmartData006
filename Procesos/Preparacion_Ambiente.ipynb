-- %%
%python
dbutils.widgets.removeAll()

-- %%
create widget text storageName default "adlslakedev006";

-- %%
DROP CATALOG IF EXISTS catalog_sd CASCADE;

-- %%
CREATE CATALOG IF NOT EXISTS catalog_sd

-- %%
CREATE SCHEMA IF NOT EXISTS catalog_sd.raw;
CREATE SCHEMA IF NOT EXISTS catalog_sd.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_sd.silver;
CREATE SCHEMA IF NOT EXISTS catalog_sd.golden;
CREATE SCHEMA IF NOT EXISTS catalog_sd.exploratory;

--CREATE VOLUME IF NOT EXISTS catalog_smartdata.raw.datasets;

-- %%
----DESCRIBE VOLUME catalog_smartdata.raw.datasets

-- %%
--show volumes in catalog_smartdata.raw;
